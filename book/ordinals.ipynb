# %% [markdown]
# # Ordinals
#
# <https://docs.ordinals.com/>
#
# <https://github.com/ordinals/ord/blob/master/bip.mediawiki>
#
# 核心是给所有挖出来的聪编号，从0开始。比如第一个block (height = 0)，也就是创世区块，挖出了50个btc，也就是 50_0000_0000 聪，那么这些聪的编号就是聪 0 到 49_9999_9999。
#
# 再有就是跟踪这些聪的转账历史，从而记录下每个聪的来龙去脉。
#
# 最终就是，对于一个utxo，我们需要知道，对于它所包含的币中的每个聪，其编号是什么。
#
# 这里的难点是跟踪聪的转账历史。btc本身并不区分同一个utxo中的所有聪，因此我们需要为其强行赋予一个输入到输出的映射关系。
#
# 直观上讲，比如我的一个utxo中包含了编号为1，3，5，7，9的聪，然后我支付3聪给A，1聪作为找零给我自己，还有1聪作为交易手续费给了矿工，那么A将得到1，3，5，我自己得到7，矿工得到9。这个非常符合直观，因此比较好理解。当然，确实有一些corner case需要考虑。
#
# ## 几个实验
#
# ### 1. 计算一个block挖出来的币的第一个聪的编号

# %%
# test data from f2pool.com
block_height = 574993
correct_ord = 1768741250000000

# 每4年减半，也就是没210000个区块减半，初始奖励为50BTC
def get_block_reward(block_height):
    answer = 50 * 10**8 / 2**(block_height // 210000)
    assert answer == int(answer)
    return int(answer)

def get_number_of_the_first_block_satoshi_brute_force(block_height):
    acc = 0
    for height in range(block_height):
        acc += get_block_reward(height)
    return acc

def get_number_of_the_first_block_satoshi(block_height):
    epoch = block_height // 210000 # 第几个4年周期
    acc = 0
    for e in range(epoch): # 每个epoch直接计算 
        acc += 210000 * get_block_reward(e * 210000)
    epoch_start = epoch * 210000
    epoch_offset = block_height - epoch_start
    epoch_reward = get_block_reward(epoch_start)
    acc += epoch_offset * epoch_reward
    return acc

calculated_ord = get_number_of_the_first_block_satoshi(block_height)
calculated_ord_brute_force = get_number_of_the_first_block_satoshi_brute_force(block_height)
assert calculated_ord == calculated_ord_brute_force
print('calculated_ord:', calculated_ord)
print('correct_ord:', correct_ord)
assert calculated_ord == correct_ord
print('OK')
# Out:
# calculated_ord: 1768741250000000
# correct_ord: 1768741250000000
# OK

# %% [markdown]
# ### 2. 找到制定编号的聪目前在哪个UTXO中，归谁？
#
# 首先找到挖出它的block，然后根据转账历史一个tx一个tx的跟踪，直到找到当前的UTXO，从而找到其当前所有者。
#
# 因此一个聪经历的转账次数越多，找到他就越麻烦。比如我们来试着找一下看看。

# %%
import os, requests, json

# 测试地址
test_address = '39C7fxSzEACPjM78Z7xdPxhf7mKxJwvfMJ'
test_sat = 4529167619254
test_sat_block = 905

# from https://ordiscan.com/address/39C7fxSzEACPjM78Z7xdPxhf7mKxJwvfMJ/rare-sats we knows this sat belongs to this address

# 首先计算这个sat对应的block
def get_mined_block_number_from_sat(sat):
    epoch = 0
    epoch_start = epoch * 210000
    acc = 0
    epoch_full_reward = 210000 * get_block_reward(epoch_start)
    while acc + epoch_full_reward <= sat:
        acc += epoch_full_reward
        epoch += 1
        epoch_start += 210000
        epoch_full_reward = 210000 * get_block_reward(epoch_start)
    
    epoch_block_reward = get_block_reward(epoch_start)
    epoch_offset = (sat - acc) // epoch_block_reward
    block = epoch_start + epoch_offset
    return block

block = get_mined_block_number_from_sat(test_sat)
print('block:', block)
assert block == test_sat_block

# from https://ordiscan.com/sat/4529167619254 we knows this sat is mined in block 905

def get_cache_fn_content(fn):
    fn = f'ordinals-data/{fn}'
    # if file does not exists, return None
    if not os.path.exists(fn):
        return None
    with open(fn, 'r') as f:
        return f.read()

def put_cache_fn_content(fn, content):
    fn = f'ordinals-data/{fn}'
    with open(fn, 'w') as f:
        f.write(content)

web_request_cc = 0

def reset_web_request_cc():
    global web_request_cc
    web_request_cc = 0

def get_web_request_cc():
    global web_request_cc
    return web_request_cc

def get_web_content(url, fn=None, **options):
    global web_request_cc
    web_request_cc += 1

    if fn != None:
        fn_content = get_cache_fn_content(fn)
        if fn_content is not None:
            return fn_content
    print(f'fetching {url}')
    r = requests.get(url)
    content = None
    if 'allow_404' in options and options['allow_404'] == True:
        content = ''
    else:
        assert r.status_code == 200
        content = r.text
        assert content != None
    if fn != None:
        put_cache_fn_content(fn, content)
    return content

def get_block_hash_from_height(height):
    fn = f'block_hash_{height}.txt'
    url = f'https://mempool.space/api/block-height/{height}'
    hash = get_web_content(url, fn)
    assert len(hash) == 64
    return hash

def get_block_txs_from_height(height):
    hash = get_block_hash_from_height(height)
    url = f'https://mempool.space/api/block/{hash}/txs'
    fn = f'block_txs_{height}.txt'
    content = get_web_content(url, fn)

    obj = json.loads(content)
    assert len(obj) >= 1
    assert obj[0]['vin'][0]['is_coinbase'] == True
    return obj

def get_tx_from_txid(txid):
    assert len(txid) == 64
    url = f'https://mempool.space/api/tx/{txid}'
    fn = f'tx_{txid}.txt'
    content = get_web_content(url, fn)

    obj = json.loads(content)
    assert obj['txid'] == txid
    return obj

def fill_vin_of_tx(tx):
    assert len(tx['txid']) == 64

    for vin in tx['vin']:
        if vin['is_coinbase']:
            vin['prev_tx'] = None
            continue
        txid = vin['txid']
        vout = vin['vout']
        prev_tx = get_tx_from_txid(txid)
        vin['prev_tx'] = prev_tx
    
    return tx

def get_tx_spent_of_vout(txid, vout):
    assert len(txid) == 64
    assert vout >= 0

    fn = f'tx_spent_at_{txid}_{vout}.txt'
    url = f'https://mempool.space/api/tx/{txid}/outspend/{vout}'
    content = get_web_content(url, fn)
    
    obj = json.loads(content)

    if obj['spent'] == False:
        return None
    
    ret = (obj['txid'], obj['vin'])
    assert len(ret[0]) == 64
    assert ret[1] >= 0

    return ret

def get_tx_fee(txid):
    assert len(txid) == 64
    tx = get_tx_from_txid(txid)

    fee = tx['fee']
    assert fee >= 0
    return fee

    # fill_vin_of_tx(tx)

    # acc = 0
    # for vin in tx['vin']:
    #     assert 'prev_tx' in vin
    #     prev_tx = vin['prev_tx']
    #     value = prev_tx['vout'][vin['vout']]['value']
    #     acc += value
    
    # for vout in tx['vout']:
    #     acc -= vout['value']
    
    # assert acc >= 0

    # return acc

assert get_tx_fee('6db71e70bd0e5b9f2cc0678ff2bdb47215e2adc68dc72bdac973d93c76a54b7b') == 130_0000

def get_vout_for_offset(tx, offset):
    assert offset >= 0
    acc = 0
    idx = 0
    for vout in tx['vout']:
        if acc + vout['value'] > offset:
            return (idx, vout, offset - acc)
        acc += vout['value']
        idx += 1
    return None

def trace_sat(pos):
    txid = pos[0]
    assert len(txid) == 64
    offset = pos[1] # offset in all output sat's
    assert offset >= 0
    tx = get_tx_from_txid(txid)

    # find the output
    acc = 0
    tmp = get_vout_for_offset(tx, offset)

    correct_vout = None
    correct_n = 0
    correct_offset = 0
    if tmp != None:
        correct_n = tmp[0]
        correct_vout = tmp[1]
        correct_offset = tmp[2]
        assert correct_n >= 0
        assert correct_offset >= 0
    
    if tx['vin'][0]['is_coinbase'] == True and correct_vout == None:
        # destroyed
        print('destroyed')
        return None
    
    # not fee
    if correct_vout != None:
        spent_at = get_tx_spent_of_vout(txid, correct_n)
        if spent_at == None:
            # not yet spent
            return None

        spent_at_txid = spent_at[0]
        spent_at_vin_idx = spent_at[1]

        spent_at_tx = get_tx_from_txid(spent_at_txid)
        fill_vin_of_tx(spent_at_tx)

        acc = 0
        vin_found = False
        for vin in spent_at_tx['vin']:
            assert 'prev_tx' in vin
            prev_tx = vin['prev_tx']
            assert vin['txid'] == prev_tx['txid']

            if vin['txid'] == txid and vin['vout'] == correct_n:
                vin_found = True
                break

            acc += prev_tx['vout'][vin['vout']]['value']
        assert vin_found == True

        return (spent_at_txid, acc + correct_offset)
    
    #print('spent as fee')

    assert tx['status']['confirmed'] == True

    block_height = tx['status']['block_height']
    assert block_height >= 0
    block_hash = tx['status']['block_hash']
    assert len(block_hash) == 64

    block_reward = get_block_reward(block_height)
    txs = get_block_txs_from_height(block_height)

    coinbase_txid = txs[0]['txid']
    
    for tx in txs[1:]: # skip the coinbase tx
        if tx['txid'] == txid:
            break
        fee_of_this_tx = get_tx_fee(tx['txid'])
        block_reward += fee_of_this_tx
    
    return (coinbase_txid, block_reward + correct_offset)

reset_web_request_cc()

tx_list = get_block_txs_from_height(test_sat_block)
coinbase_tx = tx_list[0]

# current position of this sat is defined as (txid, output_offset)
cur_pos = (coinbase_tx['txid'], test_sat - get_number_of_the_first_block_satoshi(test_sat_block))

n_transfer = 0
while True:
    tx = get_tx_from_txid(cur_pos[0])
    assert tx['status']['confirmed'] == True
    block_height = tx['status']['block_height']
    print(f'cur_pos = {cur_pos}, cur_height = {block_height}, n_transfer = {n_transfer}')

    next_pos = trace_sat(cur_pos)
    if next_pos == None:
        break
    cur_pos = next_pos
    n_transfer += 1

print('final_pos', cur_pos)
print(f'total cost {get_web_request_cc()} web requests')
# Out:
# block: 905
# cur_pos = ('4b4642c2f07835ca1299b7085c08d8702d66e659ff8dde9e6091661834860b19', 4167619254), cur_height = 905, n_transfer = 0
# cur_pos = ('6db71e70bd0e5b9f2cc0678ff2bdb47215e2adc68dc72bdac973d93c76a54b7b', 699433619254), cur_height = 130796, n_transfer = 1
# cur_pos = ('836cbc134a0ebfda370803a54806481da900da3053524d44b7f863d2e9ba9abb', 699415919254), cur_height = 188489, n_transfer = 2
# cur_pos = ('46efa20155e5334f8c73262121307ff61e55fad4f3c9ac30dcb5a43b8a44dd70', 699415919254), cur_height = 192026, n_transfer = 3
# cur_pos = ('c4de30ff3badbcb8f2f17dc0f2e65789f71e2eaa51c03b6f471efbf171273844', 699415919254), cur_height = 212094, n_transfer = 4
# cur_pos = ('5bf2541a26a20248580b8c2258af5c087fb4e150fd3d6f01e3cf523e530b1963', 699415919254), cur_height = 217468, n_transfer = 5
# cur_pos = ('820dba067b6e3d67ada05623425908809757ec1f1ceb1031782d6d5e2e2e0814', 699415919254), cur_height = 224348, n_transfer = 6
# cur_pos = ('ad6b5cd64a150129909833d2d3ea79d221213090b5ce99395584f8d26a1afc98', 199415919254), cur_height = 257891, n_transfer = 7
# cur_pos = ('64e6f8965c05b3b129e0a133c569f0c6efa5f1d4443738ed818148c6cefcba32', 199415919254), cur_height = 265464, n_transfer = 8
# cur_pos = ('6b42ee887e94a013a8949046a44ab0f8f6b0c39c7f4818d1cfc546c9b58d8a0b', 99415919254), cur_height = 278540, n_transfer = 9
# cur_pos = ('cb94dbc1e054e61aeb91be4d21fabb31f150bce1ccb07821078b6112a30f4d51', 99415919254), cur_height = 284771, n_transfer = 10
# cur_pos = ('598e98ad82b805b9e671e66faebca27aac95ed8fd87a0ade715a77341faeb27c', 49415919254), cur_height = 286607, n_transfer = 11
# cur_pos = ('b5a6d83995ffe461ddc4e60b3b3d4d53b12dc6f3b0acd8b32e2807b0bab4b528', 49415919254), cur_height = 296726, n_transfer = 12
# cur_pos = ('87eab49d375c2d6b27397ad680b1d4c2021b355380e4d055e5ffd025993bdd62', 49415919254), cur_height = 317181, n_transfer = 13
# cur_pos = ('d306a870cd4724a812c80835c5e251796c0c4d4dd6cc57f0c92d15bb45f08a24', 49415919254), cur_height = 336393, n_transfer = 14
# cur_pos = ('2b924e34c1e6c9eca51fe0b4a6a1f17255734c20ac0874c1f05bf5c8c418a6e2', 49415919254), cur_height = 382758, n_transfer = 15
# cur_pos = ('43f8331dac341079d235106ac389f6a5244e430e247bc509b3658e32dd65f1b1', 49415919254), cur_height = 382771, n_transfer = 16
# cur_pos = ('b6355b3d03e265234cfb5301d5a4c267742876219f4092a6383abba50b4b1e70', 29415919254), cur_height = 382776, n_transfer = 17
# cur_pos = ('cc1bd5c37b1d26f69e38f4f2abd558b5cc5e3cd040f6c5f7db1c635e7ca74f6f', 9415919254), cur_height = 386740, n_transfer = 18
# cur_pos = ('2b074c023c29335cc9dd1fdc10e04c33672e6e8739ca1a7b717b9f15d50c0ced', 9415919254), cur_height = 388616, n_transfer = 19
# cur_pos = ('3085f9fbd86597b5f01c8f266a7e2327a32365eb6a00c08aff324026bd1110ae', 9415919254), cur_height = 388644, n_transfer = 20
# cur_pos = ('7dc308ca7c63432ccd0c5dd30c3133346d60a4eccc97db78fe3a062ebdbf9c06', 9415919254), cur_height = 389599, n_transfer = 21
# cur_pos = ('60eae2dc37f2afe7c87bc27540ebd4daccecedf5662cdc17c8b34e12afe22216', 9415919254), cur_height = 390006, n_transfer = 22
# cur_pos = ('99eb528d3d4fc6588e8a3945dcd5983d098680f290c7e3a5be54492b8ff87164', 17515180839), cur_height = 390260, n_transfer = 23
# cur_pos = ('564938f599a16ee9266f3c57c6e0141064d42ef410139a0e35dc244edcbc3207', 1467818352), cur_height = 390641, n_transfer = 24
# cur_pos = ('1267528d7c09b8c2eb2f41473604b454119224deae67285b08fd52fa55cf18a9', 1784818352), cur_height = 393123, n_transfer = 25
# cur_pos = ('01fa33326e80f864b166b04f386cd80263c02ed2dc7a60bc3ff1dfe4ab3b8a48', 29423568918), cur_height = 393188, n_transfer = 26
# cur_pos = ('213b28e8553ad20d8c7785976afcfa557169f1e244f6ddc9b1daa38226cb0dc6', 1204969907), cur_height = 393189, n_transfer = 27
# cur_pos = ('ebb015be7c3723dcffefeb581c3b5e06b2f20c56bbd8452611ff8fa3a4311d1b', 1204969907), cur_height = 393230, n_transfer = 28
# cur_pos = ('c0d8012861b5300c23151434c2c57ffa152816942a17611f0c5c90fb4e0fe985', 3222945543), cur_height = 393232, n_transfer = 29
# cur_pos = ('deb74d5449cf8aa55040e7abab5211c5243252f2cced5db80315d10844ae49cf', 3222945543), cur_height = 393239, n_transfer = 30
# cur_pos = ('4fa45184fa7258ad352c85d9c0ddb2794c51bf801f5306532558f23af49fa448', 3222945543), cur_height = 393244, n_transfer = 31
# cur_pos = ('d6069b673aec89a2d7496310f962cfff286f362449d7be467c3b5e28c7a2aee8', 3211105153), cur_height = 393248, n_transfer = 32
# cur_pos = ('1090fb9d3211cc77a050ed3a29313d55899d9e036bb5cc324585f05c914ebcca', 2829043486), cur_height = 393256, n_transfer = 33
# cur_pos = ('b728de25d9a79ca3c15a267b1d17ebd32450a609a574b75a645baf710f94e7da', 2743070413), cur_height = 393263, n_transfer = 34
# cur_pos = ('eddaab987b08c0a2ff7f0a6f0bfeb5e6a083d32b4d2a5ecdcb0b92ef4aac1a9e', 18108413411), cur_height = 393265, n_transfer = 35
# cur_pos = ('acaced07a5dd8e8897aacf696b168e82f104076db90efa2cd967fe1e900c5d45', 229962384543), cur_height = 426637, n_transfer = 36
# cur_pos = ('6e75c1a2a87fe0298adabe23190f81d3a674948f0ec654197461de4fca377f9c', 176672311743), cur_height = 428133, n_transfer = 37
# cur_pos = ('1baf3c3593c0eb6ab94a023bdc2a60b5b4cfec3679bf2fdcb9ea8df0dc2da4d1', 126672311743), cur_height = 430119, n_transfer = 38
# cur_pos = ('d10f5d740a01bf3b82abc68c31de22018ad21d97d37aee75825642b77f707a51', 76672311743), cur_height = 431299, n_transfer = 39
# cur_pos = ('1fde762cb8df403caf99ddb2dc3b133c6364db9f7b5525b0481c0c136b2076a8', 59672262843), cur_height = 433429, n_transfer = 40
# cur_pos = ('be5ded930a6fc5d97dab84d6734914c28eff6849f0c50473b0a879cf8ef96820', 36672378943), cur_height = 433948, n_transfer = 41
# cur_pos = ('abac6589e4a2fd3386d8d6fcd356b6965b96e7738b4e83789b1676fed01cd2dc', 36672296243), cur_height = 433949, n_transfer = 42
# cur_pos = ('dab6d54103718ffef454a3fa8dd1f86d4001234ffdf73269398fc1598821c077', 36672296243), cur_height = 433950, n_transfer = 43
# cur_pos = ('4b6b21f0e97a62d06026912799f54b5829b47563fabc1a59b49207471498d9fa', 36614611753), cur_height = 433951, n_transfer = 44
# cur_pos = ('6bf42506ab04a0748150423e738083e544a0ee2e4436c60a0b861a557b8d5afd', 36609378891), cur_height = 433953, n_transfer = 45
# cur_pos = ('93c2effe3cb40d3df0be01a68a04c09a012af9c3362fc90cbfeda4c7a3a88f62', 36116779354), cur_height = 433956, n_transfer = 46
# cur_pos = ('10cc4503d2a792a2991480fb97d62e9e0cd3451eecc7f0439617c2c347b696d2', 36116779354), cur_height = 433958, n_transfer = 47
# cur_pos = ('110186a4b7c72fd4e5f3f61a4d7be2ca1c1d2b4fc0166ac8f367bbca4e96e6a5', 35988627353), cur_height = 433961, n_transfer = 48
# cur_pos = ('2669c8e42ca3484f9c0891a9bc99490899f8faff24d80befe3304fab5989de42', 35987176163), cur_height = 433962, n_transfer = 49
# cur_pos = ('2b452327d180238ee17a0b315e03d622df1603885982583306b17eba1cb2e87b', 35987176163), cur_height = 433964, n_transfer = 50
# cur_pos = ('61399797124f64131220609b5dbe05b0d19a2683f4af87d77bc54a283302bc93', 35907213063), cur_height = 433966, n_transfer = 51
# cur_pos = ('05d91905afa12b6428ae91e5c9221a1f48724e7615c1748f285abfbdd80dac6a', 35800183970), cur_height = 433969, n_transfer = 52
# cur_pos = ('b579e10428507b26c827494186e8834769296c875c3ddc2652084bef58bdcdfa', 35800183970), cur_height = 433974, n_transfer = 53
# cur_pos = ('99eb70544bc50fa93a354ba1c77e5f80c8c9dff1ac89c728a7b28d49f578f94f', 35747664814), cur_height = 433976, n_transfer = 54
# cur_pos = ('cc4d90f434ef17b0fa6a1ffe396622ffbb17b788c392c276e2d0b4a30c477dfc', 35714438665), cur_height = 433978, n_transfer = 55
# cur_pos = ('163b50da263ca612efbb8bb7e49f28ce64a352938310eb0cd7c107a9c5a5ab3c', 29433983155), cur_height = 433983, n_transfer = 56
# cur_pos = ('0da1e8bb660e9dad1aa840f1de8c01024b561ee712bf8b94983cd07e6963fc58', 29423258857), cur_height = 433984, n_transfer = 57
# cur_pos = ('27b65c0ea4643d2f82de28d44de5a46826334c6847c4c42e9afe569d3aa25a79', 29423258857), cur_height = 433985, n_transfer = 58
# cur_pos = ('3ad144d2deea70bf8572a99b2c12bb4035f31a622fea96194cb2af6a04d40a0d', 29358541858), cur_height = 433989, n_transfer = 59
# cur_pos = ('7b30bd993a6be4157330e92aca4f6092b86576be39e5223cab028603634d9fde', 29354059358), cur_height = 433991, n_transfer = 60
# cur_pos = ('5d04f243e4184069b2652a448659a82531f41d0293cd9dc097af8eebeeacea88', 29048250022), cur_height = 433992, n_transfer = 61
# cur_pos = ('8c745c02e0db884618158948614aca42f1cda835b53140fe670368e4e8321cda', 28982740605), cur_height = 433994, n_transfer = 62
# cur_pos = ('07e41781e145fe79aad28de2db96693428ffac586fbff9328a8e1ab1761111c1', 28772234443), cur_height = 433998, n_transfer = 63
# cur_pos = ('fdcdefb1cc0bd65fd628ad560dc1c01c632ad0fc4049a472ef4f22f367942fd3', 28736168850), cur_height = 433999, n_transfer = 64
# cur_pos = ('0f4396891f3379bd6563dbcdc97856ac4b4354137fb18e811062662d79b24636', 1068812195544), cur_height = 467548, n_transfer = 65
# cur_pos = ('49a768311b9926b118dfb4f3ca9bd0d3ba35ce0442c3cdd04310d2bb23c0953c', 967188301444), cur_height = 483959, n_transfer = 66
# cur_pos = ('91581eefe79ec99ee197efd2251115a499737c987ac922bc551c663b4fc413d5', 967188301444), cur_height = 487000, n_transfer = 67
# cur_pos = ('5c202cbe377c3757a1b626b39200533b8e76af2f4a5204a5bee941e4d20911c2', 917189982744), cur_height = 521865, n_transfer = 68
# cur_pos = ('6e3a9c8650abde49aa71c62b0cc83c70101ff92ee6f0e3fefeee80f52fe2d8b5', 887199986533), cur_height = 565010, n_transfer = 69
# cur_pos = ('e72e6ed72e558c5dab8b01ea035f917a39c5861920189ba36a4d9b5117d0b30e', 473972570207), cur_height = 568878, n_transfer = 70
# cur_pos = ('c3108bf559a161d3a273b787b539283c71ac42d170296e9f668a84aa7bcc6e01', 413972526966), cur_height = 594659, n_transfer = 71
# cur_pos = ('447ce2103364332e07593ba83ef9b27d1ab3e69cbd8096e02b98f108afa77e1f', 217178477337), cur_height = 596469, n_transfer = 72
# cur_pos = ('b822c4774760dc4d4ee635c1694c4e99c59b08ef4b6899a4f06a1b3aa7201527', 197178477337), cur_height = 597231, n_transfer = 73
# cur_pos = ('9cb75be13f20c0d024651888aeab787508be17b52f1e4ef93483b0236e230cd5', 157178477337), cur_height = 597729, n_transfer = 74
# cur_pos = ('30fa2cf5cb67065e23c093563e126aaee6dd691e37188d2b28273ea481def191', 117178477337), cur_height = 599291, n_transfer = 75
# cur_pos = ('7362c8a6c84910968c7cf90472611f0df39d41324935820a4382fe2a69ce9688', 97178477337), cur_height = 600946, n_transfer = 76
# cur_pos = ('f082869b2eb8fe9ab9f0c9b2a6291aff6e0fb84f93bd4054b7cccf9c19d4455d', 77178477337), cur_height = 601435, n_transfer = 77
# cur_pos = ('4dc1c789c5a161ef313aa00016f7134bbc130c89110ba5d09476c77ae0cb6cb8', 17178477337), cur_height = 601969, n_transfer = 78
# cur_pos = ('638b5e4dbf33b820a1553b8216d740073d841e3228a6061e61c5412594ded6cc', 7178482841), cur_height = 615318, n_transfer = 79
# cur_pos = ('d1ebcf8997596698c7e86d4a9499c078f6f48055539262fb67e409c93b9f5edc', 7178477320), cur_height = 615319, n_transfer = 80
# cur_pos = ('4f2e69eaa45ac1ef1e37e7deec0e0e56da48630a932e849a663009057d31e13c', 7169860107), cur_height = 615319, n_transfer = 81
# cur_pos = ('199c7ee26e5c51670c9a1cabf56d6ae4faea258f32ef666a59ccd7dc4994f5d7', 7169860107), cur_height = 615321, n_transfer = 82
# cur_pos = ('25596f94ec74290c4f91ca1aae50f2fc15675cef89ae84ed43715f898d6157f0', 7166375397), cur_height = 615325, n_transfer = 83
# cur_pos = ('1e8b198a2fa49ad3ad093da65c4ce38d2aa42d0a36a4b11a98fe4f6a48613fbd', 7165705602), cur_height = 615325, n_transfer = 84
# cur_pos = ('dd18ba7e1653c7e3d1ab216ac6fe35d925a985d898c1553fc7fbbb3b0c0218f4', 7150504963), cur_height = 615326, n_transfer = 85
# cur_pos = ('72cf8256130b6d5db95de5c545f15fa6b85555987d94ed83eada5114a1dd7140', 7150504963), cur_height = 615327, n_transfer = 86
# cur_pos = ('0b576ac6457a389074d04666fdf6a312fc7e7c4f25da09c80621f9cd8ffe7d77', 7122320104), cur_height = 615330, n_transfer = 87
# cur_pos = ('bc1777089294c57913e6bd7149bd0e6321d96b0347a17cc42961f7007848f1e3', 7108029442), cur_height = 615331, n_transfer = 88
# cur_pos = ('de564c66ee2588f369c2d79c357ab42531699f3bf86e8dff9396453e2821b6b1', 7094527001), cur_height = 615332, n_transfer = 89
# cur_pos = ('5e42ad43c51068cf289db6482242fba7539b29929e954481c083ec2382c20009', 7091565498), cur_height = 615332, n_transfer = 90
# cur_pos = ('42a4c9cf9903ca3947f70bde7bb9a542bb33a9a70361f545dbacd3d4948d5435', 7087353292), cur_height = 615336, n_transfer = 91
# cur_pos = ('4473c03c557f37520eea3ba8fd869b2c73238eeef50d51df460106de36fc6915', 7050884779), cur_height = 615336, n_transfer = 92
# cur_pos = ('3abd5d4efdd4286264ec7bb8f11b55f9b990fde60151f729567bdb609f3f554c', 7050884779), cur_height = 615337, n_transfer = 93
# cur_pos = ('a0b6948947d58ea9005005e5fdfcab3464158b69d4e737aa97b908ba2964a5c3', 7050607592), cur_height = 615338, n_transfer = 94
# cur_pos = ('9afb6614e1d120e23b926fb1ebda94f9eefb68d2c858bd4a468436705d81022d', 6991874282), cur_height = 615339, n_transfer = 95
# cur_pos = ('2ab2b8135fc74696a5500f93ec6b7e38a98c491fb8e5eeb250c6c860746eebf5', 6950672800), cur_height = 615343, n_transfer = 96
# cur_pos = ('eda6967a11211598c9a162772b8170bc1729dd532b1aed2aa1d47de2c730e906', 6945047578), cur_height = 615344, n_transfer = 97
# cur_pos = ('4f32c2101040078884bce37a3b4d370e08d805acc44ceb6c7282c0cd10ba6d8f', 6941449967), cur_height = 615344, n_transfer = 98
# cur_pos = ('ee0707685adb158b2b45da02785d06a76dc8837715b341e6d7bd831e1560fa70', 6932162156), cur_height = 615346, n_transfer = 99
# cur_pos = ('ebd48a70b0e37da2782aaad44e7d2ae80f3d6909fbeb7ac638e49d9c8cde613c', 6913564982), cur_height = 615349, n_transfer = 100
# cur_pos = ('c04fe2c8d8d685df82350f9745cdff8e71a819a65df9c65c9e9b5ec27d1a0265', 6893512686), cur_height = 615352, n_transfer = 101
# cur_pos = ('9bcf90445955537f3fabbb8c0906576667c668eb64e2309b7cd406c28fa2b91d', 6890024537), cur_height = 615353, n_transfer = 102
# cur_pos = ('7f5731aafba80b5cfb4a6ba1db8d5c7d38ca3b2c01dfe939ed0f736640e1de41', 6886742235), cur_height = 615353, n_transfer = 103
# cur_pos = ('db0c38d8d32c8b0f5bab960a69af982dd691a75eea0f1d7ee66910843b34d984', 6885624272), cur_height = 615354, n_transfer = 104
# cur_pos = ('c630caa2a67ba11f8e6616c29134bfc0ec0a4a67dde16c0629c24b37e65a7d3e', 6858955798), cur_height = 615356, n_transfer = 105
# cur_pos = ('dfca6669738faacfe753d5fa2643297890ebfbbf115e88346fb083ec8cd20afd', 6855884354), cur_height = 615356, n_transfer = 106
# cur_pos = ('cff3b8d8d4bffb45e7d93ca7b24d57426d9c54717859ea3d0d1d3cd40eb9b9ce', 6852120510), cur_height = 615357, n_transfer = 107
# cur_pos = ('4f095f696e3ab66f97a08a30aec1c6dd29748b5fc5d340e0fb2c16cb26051dba', 6846515036), cur_height = 615360, n_transfer = 108
# cur_pos = ('2fcc6d086615d28cc676d3b2cfa46eb120e39b6cf159f9f39817224a741f46e6', 6831470489), cur_height = 615360, n_transfer = 109
# cur_pos = ('c638afea8a70858164d9ce0082ff3348ed7a01483cd34cf9700db55bc67206fc', 6756817147), cur_height = 615363, n_transfer = 110
# cur_pos = ('54a26c0328c43bbac5525329d545a9e4f42624118212641961e25a6bed23f593', 6712659107), cur_height = 615368, n_transfer = 111
# cur_pos = ('357e9e73fea3847420d9a97f0389e0ea713f80280744d6f6af2b1bb8d21e8a1a', 6698042145), cur_height = 615368, n_transfer = 112
# cur_pos = ('6bec422aa7ea4daa3bdbf4990cc219a6e85514b4b19510a3e6aeaa752d515e90', 6659500155), cur_height = 615368, n_transfer = 113
# cur_pos = ('76f07628da4dac812299bbeebb7dc2632f39876918abbf30b7435de6789d0589', 6636123938), cur_height = 615368, n_transfer = 114
# cur_pos = ('ec11a891ef2f944b05fb99b7efb4626f6be45d28b4dd0c2ba423587a8e20cb49', 6618166692), cur_height = 615368, n_transfer = 115
# cur_pos = ('cf38ff8b0977c9303e2b1490817c4aaa3638756338ffa5a8db21f1c9368beaf6', 6606581291), cur_height = 615368, n_transfer = 116
# cur_pos = ('ca0aa73732025d9289086ec5c079881e76dbbcdcd6a779564250c8ecad914610', 6580687445), cur_height = 615369, n_transfer = 117
# cur_pos = ('917a1e9c1435d5efbae778187626fb63f110d84611b32be4c3de24aae92f780f', 6580687445), cur_height = 615369, n_transfer = 118
# cur_pos = ('1e8b8c9b53136fa65e5df14853bbf27f73e79e10702f7800fe498b76b1b71f50', 6579783564), cur_height = 615369, n_transfer = 119
# cur_pos = ('86a0a01f36a8779d1fcef9a0d2619205347dd99f19ffb30f81054f293407ed7c', 6520605294), cur_height = 615369, n_transfer = 120
# cur_pos = ('df5ef4584a82855c5bce2678b9e17d78b2bd1780d41bf4fff89c5fb888505488', 6519706201), cur_height = 615369, n_transfer = 121
# cur_pos = ('babd4020ed653a67b186f4af78a4d9347c85de0b0ed7a33cf17eab6a4afca110', 6503412460), cur_height = 615369, n_transfer = 122
# cur_pos = ('b330bb4274e16f9137baa8e1d7614cf0222e91554a0df44f4607badf5719ef62', 6502136665), cur_height = 615369, n_transfer = 123
# cur_pos = ('59777e3cd1ce0eb208536579244dff2ae9fb077c99c9104d2db8e8d761cd886f', 6352472719), cur_height = 615370, n_transfer = 124
# cur_pos = ('28f94f93b1ef5156607d7cba4650983cafe349f343179915687084f77acb2e54', 6341815448), cur_height = 615371, n_transfer = 125
# cur_pos = ('a15ce0071ea63f677552e1ca1463e3c2d930ccbc319de6e1712beccd5e78b7a2', 6329306989), cur_height = 615372, n_transfer = 126
# cur_pos = ('2ea24de71411f8154e622d42b907ce7e85ba5fa0dcf92e3dac2b71d29f3f261a', 6285928387), cur_height = 615373, n_transfer = 127
# cur_pos = ('f26a8f36e21d431462fa601041cc9c0fc783a4fea71a01a9de271b513241dcea', 6236293305), cur_height = 615373, n_transfer = 128
# cur_pos = ('12bfe2be3ac3ac49a7f0c570fc204af1c8f0c11abd6b5c440121a37c0189bf66', 6212632462), cur_height = 615373, n_transfer = 129
# cur_pos = ('c70eb79eaf811f3f99a9f8fb3ba51624424a423af7a4bdda1139abdcf307017a', 6212502805), cur_height = 615373, n_transfer = 130
# cur_pos = ('e616c64a112266af5e41c86b32052cdfceea87381e548e19fb45fd4bcaf7d42c', 6206023916), cur_height = 615374, n_transfer = 131
# cur_pos = ('daf3be45a4c20c6c9622693fb031707e158116bc25eaa5291731e120b30b6d93', 5974293974), cur_height = 615374, n_transfer = 132
# cur_pos = ('ead67688008c4c47b54097812beaa6e27dcbafa90c0eb5ec2ebd67d819c06a3a', 5847955922), cur_height = 615374, n_transfer = 133
# cur_pos = ('984cba5eb0a2ab3e223d0db9fa88248fefddffccc536a7f07da43a4c362b3585', 5846364471), cur_height = 615374, n_transfer = 134
# cur_pos = ('7bf6071cae81a185aeb49ab7880b814fcf945d4049af1b07d0b72a270deb6c2c', 5843829511), cur_height = 615376, n_transfer = 135
# cur_pos = ('a674159ca6c6c7c19ba0abe62f919a25fd323ddaf96acdb8fbfaad830fb2af25', 5843829511), cur_height = 615377, n_transfer = 136
# cur_pos = ('06e68b6c0d02b38c0b8ea14e8b03c5c637cccd4739a73109de84fd1ad378d226', 5840021727), cur_height = 615379, n_transfer = 137
# cur_pos = ('9d5e83bda7c5d587c05d2ac4cae974c6c31c57f541ae28640b363ddc0e243605', 5621200271), cur_height = 615381, n_transfer = 138
# cur_pos = ('9c9812fb0f19427c32e4c065b474fa64850b72acb7b9fd74fac68a116cbcbed4', 5619446947), cur_height = 615384, n_transfer = 139
# cur_pos = ('775440f07a84fe49b1016701ecb62614bc6f56a4a5ecb3c0bf9a4a426eaf6a50', 5619446947), cur_height = 615385, n_transfer = 140
# cur_pos = ('49149a92f54c033ab23f87ab8319ab92324960cfa45c41e9b123d7104c576f53', 5615316837), cur_height = 615385, n_transfer = 141
# cur_pos = ('000d383fb64f51c6b756de4a87a2061f3cafec2436011dede86982d84e39bde8', 5607329347), cur_height = 615389, n_transfer = 142
# cur_pos = ('b7945b6b27d15789f13e66b2a0fd93f56bb2b52e5d7b09382780826527853c9b', 5597279551), cur_height = 615389, n_transfer = 143
# cur_pos = ('848ac0d6f53396e292b1a7155a893b210c79d1f8f8bc1d2f771c15a999fe3972', 5551114474), cur_height = 615391, n_transfer = 144
# cur_pos = ('661060ea128307ddfff0075a7257bb1945f6895710da3499e446a96425d1e8d1', 5550318749), cur_height = 615391, n_transfer = 145
# cur_pos = ('94d7a236d83570835c5f2c2aff3ec92e324a2a2aae1d24be30988ff9b868a2f7', 5472949683), cur_height = 615391, n_transfer = 146
# cur_pos = ('3f2937be8dee1f9d76a665e17f245bf8db68489d8d64af79fdae1e152f60096b', 5471968952), cur_height = 615391, n_transfer = 147
# cur_pos = ('db98ff82e2f7692547d23d1b0ffa1b670db4db6341a6ce3683814aff61677827', 5419348355), cur_height = 615392, n_transfer = 148
# cur_pos = ('56e81880383e2b5f8936ec2f84806815138a4e5c974d47ec2b256645ba28d103', 5363617622), cur_height = 615392, n_transfer = 149
# cur_pos = ('926d65420ab72302b286ebc2772dfedec44519a86c77ac345d226d6e67f77ead', 5323781085), cur_height = 615393, n_transfer = 150
# cur_pos = ('2af0e1f9f0ae098520c28f41357142a24c9636a8f4285d10d9596e3171105dd8', 5323781085), cur_height = 615394, n_transfer = 151
# cur_pos = ('61bf4fb27c2ba7996b6ffd3fdcd24491eff32293c611a5bc0f68479b33f637a1', 5306677794), cur_height = 615394, n_transfer = 152
# cur_pos = ('4ee20c3df2f1968768e64b68f4c93b1120d6942d1dad93a656ec272c506ad58d', 5302170566), cur_height = 615395, n_transfer = 153
# cur_pos = ('d1a638b7599fdfc2c9b8e7baf05a07fcd8b7beba74bd3ff1add82b1c2e188d56', 5274704329), cur_height = 615402, n_transfer = 154
# cur_pos = ('21595a554fd607296d962f6cb02235d70bca9dfc33bd418fab74df0efb45f57f', 5237489450), cur_height = 615403, n_transfer = 155
# cur_pos = ('29bba492fb638a384e3320ea3e5614f31e2c4e71e8ed55fa72418e50659b07c7', 5140196659), cur_height = 615406, n_transfer = 156
# cur_pos = ('34eda3af3974ac87a869dce40c60624e1ddeda23db48c4b4eb082e9d7f5bab9e', 5135056336), cur_height = 615410, n_transfer = 157
# cur_pos = ('222a6342f5889c041ef8feb640567315982edff96c09d0efe106b9f5255cac42', 4832735552), cur_height = 615411, n_transfer = 158
# cur_pos = ('de01469814314956f8b06e47ea928a33d140051c422965ccc64db264ab657b00', 4737365548), cur_height = 615416, n_transfer = 159
# cur_pos = ('6eb019ac9d8d693105237a45c46838513da64eaebe824dea036885360dfad18d', 4672901595), cur_height = 615418, n_transfer = 160
# cur_pos = ('9458d7ea5ec7ff57254ce84616301030550c80b6ad265a6ff7431b795f5704dd', 4652181640), cur_height = 615419, n_transfer = 161
# cur_pos = ('ced484d51ce4b570efd1cbfec30f9a74078a546d9a111ad85724620e56034bf7', 4652031640), cur_height = 615424, n_transfer = 162
# cur_pos = ('7efaa30fab8eea41a907972349fd21dc4b7f93e69dc0fecb24c6840277353505', 4603831624), cur_height = 615428, n_transfer = 163
# cur_pos = ('e537f73cd7531af97258263b26eb577c33da7c8896a283417b8396d0ac27613e', 4595339955), cur_height = 615437, n_transfer = 164
# cur_pos = ('00adbddbf6f440278aef31b85d3b638fd2ee708b3779563dbfd168590c808b65', 4593750504), cur_height = 615443, n_transfer = 165
# cur_pos = ('e0087d15a779afbdbaeb1f3de51c7ac15156fdd896f0129f13274e9bd667df29', 4591680807), cur_height = 615450, n_transfer = 166
# cur_pos = ('1f92910f17ffc3580e931acbf636214e72d273962e79c96ab3f3999cfb2d4363', 4586950384), cur_height = 615451, n_transfer = 167
# cur_pos = ('7c4ef686556bc8ddfd9d5811c9eb27a0ddb1a79372bcb239c1721b3a3e2faf53', 4585427973), cur_height = 615457, n_transfer = 168
# cur_pos = ('8b604dba36d1941dc8e46e96bbb2b99152f78ea5f99cffdbf0e9f96e41a284af', 4572128280), cur_height = 615460, n_transfer = 169
# cur_pos = ('a267dd905ebdd8f8fd01254b925cbf6979dcfce189cd303a00f7c36d22b7b4a9', 4571557726), cur_height = 615460, n_transfer = 170
# cur_pos = ('fabe42cf54d913eb46cc28113921b4d03a3408ae1a723c5d11d17543ba1beeae', 4562489479), cur_height = 615466, n_transfer = 171
# cur_pos = ('3589cabc5e6354b2614cdd5103ff2b8b446ac236879ae384f95c01f9b557221c', 4557964681), cur_height = 615478, n_transfer = 172
# cur_pos = ('46b489fcf520d731b7f0230a86476b934b64089439da2bada79281576eb44927', 4557558681), cur_height = 615481, n_transfer = 173
# cur_pos = ('42f9ce10aa8555372c16cecdf845e955370a5d43cf9d2318198dc056c86418ad', 4547083799), cur_height = 615483, n_transfer = 174
# cur_pos = ('3fabac886325f44f297fe517181f1ebdd67393a59f0b78dc9f9269e2c0e80e52', 4540171550), cur_height = 615484, n_transfer = 175
# cur_pos = ('86503bc3d398fe0c93d33a27f9eb26084e8059a3d475842b0011ffdf5b9b1735', 4538995422), cur_height = 615487, n_transfer = 176
# cur_pos = ('971764537e07919f27be6b06ad92a9d5a960e69defaa177df46001d69f95bcdb', 4502994823), cur_height = 615493, n_transfer = 177
# cur_pos = ('8e3e8deb16bfd56393647fff3dc6a420809feb4930961347f70efdd6c6ec0de0', 4500233093), cur_height = 615494, n_transfer = 178
# cur_pos = ('02118757fc0a49d269ad1f448ab638615a8bb148422a05b60df7a99f7631cd4b', 4479993972), cur_height = 615496, n_transfer = 179
# cur_pos = ('7ee2857feb5e8109850648890d78adf45db18e025edeb847d9326418d4715b6b', 4479993972), cur_height = 615503, n_transfer = 180
# cur_pos = ('f723a64215bb9300e0d4a621a2130f648de80a410b9a40212da0ab034cddb116', 4478003278), cur_height = 615505, n_transfer = 181
# cur_pos = ('d0ac1884ea35d685c34e66e5174d7ca0afef00fbcbaaaa3cdd8c6f3979230835', 4455141605), cur_height = 615512, n_transfer = 182
# cur_pos = ('659be822e25fc089e39d0c55cc0c25beac85c3b5efd0151b7a9e004dc01503db', 4452809904), cur_height = 615512, n_transfer = 183
# cur_pos = ('6ede5b6475e4a616a1ba6c501b096a574749c26ccaf9a261e223384d5b66c0d2', 4435835806), cur_height = 615514, n_transfer = 184
# cur_pos = ('352c00c5de6a16568568172d2436b9b520b084ce249ca977e49f9fb8c737d07b', 4435339540), cur_height = 615519, n_transfer = 185
# cur_pos = ('dab3e62aa792090b78e2c5d3507fc5c2d3a5362b0f0483dd8672340f322ffacf', 4418027913), cur_height = 615525, n_transfer = 186
# cur_pos = ('a94e6424caf8ccb57e7973e11c60d3d9ba326dc0682a230abe59de78a05c0808', 4408462475), cur_height = 615528, n_transfer = 187
# cur_pos = ('d3671b518f92db46988564246e5983fe6d718887c80bedda9d2edd835f01bea4', 4400631983), cur_height = 615529, n_transfer = 188
# cur_pos = ('f5bcf7745852cfef91bddaff76a59c29fa90b1aee154bfa8ac423c2ba0d3a940', 4392884663), cur_height = 615531, n_transfer = 189
# cur_pos = ('4503efb316bada6536330fef71193a58953e3cd47fd5976a2a4955830febd3a4', 4282708314), cur_height = 615533, n_transfer = 190
# cur_pos = ('ea206819e2ede1b7109d673695aef8012ba0bab0cda0ebf5de23b1fdabcb7cc0', 4281471265), cur_height = 615533, n_transfer = 191
# cur_pos = ('87cb22a3b5b946e5bd050973e518345b9164afa0bbec751b3eb406838076242b', 4281000625), cur_height = 615534, n_transfer = 192
# cur_pos = ('6901eed2787db9ab93f9beb726d2acbb448242cbd8309994765e6673cbb45832', 4273530558), cur_height = 615535, n_transfer = 193
# cur_pos = ('31bff208775a05ec28840e8a3c9ce47d46aad58941b5306bd507c8e4fe412212', 4154893047), cur_height = 615540, n_transfer = 194
# cur_pos = ('478d5e2c738c724e0a129df5eb5e8a87a02ed127c8033c73f33429da77e725e5', 4072527576), cur_height = 615545, n_transfer = 195
# cur_pos = ('1c889d807029875c828c4478474fc2cb6143cdaa1ad884d0eb6f5184e61d6d49', 4051122584), cur_height = 615547, n_transfer = 196
# cur_pos = ('3d8971f2967503773a58feebbd8027cd8a2c2e90ceeecd74c729c7b49eb6cb65', 4012917816), cur_height = 615549, n_transfer = 197
# cur_pos = ('878c32461853a32aed776fe9e2de7e5abb33aef6870f452bdccbbad2ac8dd064', 4001895772), cur_height = 615549, n_transfer = 198
# cur_pos = ('d8383bcce7330be921944af92f91b625b5a5b58fe7ca205e3f86e689a9da31ed', 3976187063), cur_height = 615551, n_transfer = 199
# cur_pos = ('9498e3a928e26171bff8de1aa6de09a61459393b6a1a84ab6fb06ecc994ddd9e', 3959521197), cur_height = 615551, n_transfer = 200
# cur_pos = ('ebac835a34fe4f19f37e81587c16ff1cfa174c9134355ace6ad85b5ec0291590', 3958426052), cur_height = 615554, n_transfer = 201
# cur_pos = ('fcc65d67d64db5b294615333be87df9f38129f4ac195432b7e41d28a99929814', 3923487906), cur_height = 615558, n_transfer = 202
# cur_pos = ('5924f8cb9d4508fcb4f14a2644bcfa471b591ab66ab87d0f4a5ce9b50604d630', 3901589355), cur_height = 615559, n_transfer = 203
# cur_pos = ('2ec4c773c620247df3c8a9702ddea19e10a727d39a5a6532b9ddc218a37bae05', 3886585440), cur_height = 615562, n_transfer = 204
# cur_pos = ('d64f6ffb60ce93029925b1ba7931795ae4e547ce19eef34f7b20f61102d3e434', 3877158921), cur_height = 615563, n_transfer = 205
# cur_pos = ('d9edb8be729d73202a00f7e6c7b11705131c999ec592dd59c3fdb3612a5b8410', 3747649077), cur_height = 615565, n_transfer = 206
# cur_pos = ('b74e3e43e72562a3de1541224d5ce48a743da1c2fd9673f18aabd3e09dcb5b52', 3745843208), cur_height = 615566, n_transfer = 207
# cur_pos = ('e03f4d7ca85d7f63cfd6dfd1a3eadc4d097491a7015111935b7215520a8f7a6d', 3745038641), cur_height = 615566, n_transfer = 208
# cur_pos = ('3d22be0c2aa36061d2d7f79bb3d03d6fff058a21704f8cb58db083faed630644', 3744294600), cur_height = 615569, n_transfer = 209
# cur_pos = ('5edd064fda088e1e6af0976cf3e7f152d682497b6976a785c3ee086c1e6a93da', 3731086294), cur_height = 615571, n_transfer = 210
# cur_pos = ('ff547c464c2b5bb1b6c7ebbcdfa0e4271be92f65f9d7dded26d7ef018653f401', 3729148117), cur_height = 615575, n_transfer = 211
# cur_pos = ('5c6624f00537a0169a397cad96a59b8239dc3eec6be95db27e66f16fd29b0750', 3714529528), cur_height = 615577, n_transfer = 212
# cur_pos = ('01a0b58513a15019b3ff26d03f7dbb9f032dc7e4bc081c261bd6bbce20a378b2', 3713693478), cur_height = 615581, n_transfer = 213
# cur_pos = ('be9608625f70985a08bda57a3cf7e53a40a2125670696faffdee0ad2288fdac1', 3713693478), cur_height = 615584, n_transfer = 214
# cur_pos = ('9ed8bcfa830ebd674d15f61a2f6c8b819cf2acccd964fe7b587a1603b69f74b6', 3713693478), cur_height = 615592, n_transfer = 215
# cur_pos = ('04e31f27d2cb4adf41bca1f25cc33ac167bf82bcf610237e6b8597a7bdf51ef0', 3704176311), cur_height = 615596, n_transfer = 216
# cur_pos = ('010fc5f701c42cab437a3a9a7837c51efd58fb9e4ad34bbc4dbb0bc8138ac923', 3698589375), cur_height = 615597, n_transfer = 217
# cur_pos = ('a75abbe7d19a3ab5aeda77e8c09d60ebb70c2be30e1b04bb8c08bdd3089b683f', 3691616870), cur_height = 615601, n_transfer = 218
# cur_pos = ('505afec147b735ced23ee1386843732604707e266eafdd62af16e4b631f5fc46', 3680921827), cur_height = 615613, n_transfer = 219
# cur_pos = ('0520fd1d0de1f7bf50dd15d116946c1616d49d121cc59aa9818f53e26c3a5162', 3676827038), cur_height = 615621, n_transfer = 220
# cur_pos = ('e121a9df94bbb2417bd7e7d27fc7cef70f0293c517d73a45d4852635bea0cfa2', 3666711807), cur_height = 615624, n_transfer = 221
# cur_pos = ('7abbcfbe98d34f62f8ab1d1674bed34fe566bb164c1b447150d6f36eb98f93aa', 3666711807), cur_height = 615624, n_transfer = 222
# cur_pos = ('39925edbf7e48c71db5b50d40558237e4c6d2a9c5eab8bbd09d996ea9d83e0b7', 3663956842), cur_height = 615633, n_transfer = 223
# cur_pos = ('6a672df36de91774f3df717a3febb3c28f1d05b3a063dfb451afa294dc72a991', 3663956842), cur_height = 615636, n_transfer = 224
# cur_pos = ('db684128e7efb0bf795deccded6c7b4f56e63aa9a1163330c65992992d47e81e', 3663956842), cur_height = 615637, n_transfer = 225
# cur_pos = ('65d1c7e22e00ebaff48e7b33396065a55070fafd7beb64aba6a2f622ce94094e', 3663956842), cur_height = 615639, n_transfer = 226
# cur_pos = ('429996d280169286dd0113e5383a404e2e5cbbcccb2dc9b0b16c32558b4ca280', 3584714807), cur_height = 615642, n_transfer = 227
# cur_pos = ('447dc78de5b2e7a4fca4a7b1742d0796b1d770e68bd6016ac1d926052332f5d3', 3577784362), cur_height = 615643, n_transfer = 228
# cur_pos = ('d20338d9391cef844d08dddb3145589c6ec99adf57f2e24446233430e3a1925f', 3565202728), cur_height = 615651, n_transfer = 229
# cur_pos = ('f813e0b9ca38a3a7ebd318a3884caf2d26c0972c9730ad50a413ac2c13048856', 3560626426), cur_height = 615656, n_transfer = 230
# cur_pos = ('f7b71d0e0defea2c99a749a51d9167a3cc0794a17ab7aeff5f27a68c7ce27e78', 3527414226), cur_height = 615657, n_transfer = 231
# cur_pos = ('4a0a6a8451380380e9e1a6df6af321fb9fa385fc1b75b883097048d1ecfc2cdd', 3525687862), cur_height = 615664, n_transfer = 232
# cur_pos = ('8b84126ad9fc121b5e93ddf85298fb3005804ca737573de6428c6c5bb6c78742', 3523409506), cur_height = 615669, n_transfer = 233
# cur_pos = ('b9868126b13b5e75698c9c3583c554974faca6ef8d210ca72bd4d454e72d8cd2', 3512479072), cur_height = 615674, n_transfer = 234
# cur_pos = ('ff1e3539398437c8c65d4015a968c0d65194a93a7ee66a0220cd512221991b0f', 3488051065), cur_height = 615674, n_transfer = 235
# cur_pos = ('f06920150a8f94d86fc6a30bccdf00fde9fd151129f87cbea9aba6f1ab752f39', 3462358177), cur_height = 615675, n_transfer = 236
# cur_pos = ('c24b19e8a0137815322099e4c028f66aded37e619e261f123c2eb72d9b9c1997', 3456955879), cur_height = 615684, n_transfer = 237
# cur_pos = ('a47864aa2df12125884975d83fc8a453006861a3168906f260f75a22a195bd16', 3452165559), cur_height = 615684, n_transfer = 238
# fetching https://mempool.space/api/tx/5282194c8268d7e919aeb32e391c5119d5c27e3b1f92c2fb3d1ff51ab9bae479
# cur_pos = ('5282194c8268d7e919aeb32e391c5119d5c27e3b1f92c2fb3d1ff51ab9bae479', 3432987519), cur_height = 615701, n_transfer = 239
# fetching https://mempool.space/api/tx/5282194c8268d7e919aeb32e391c5119d5c27e3b1f92c2fb3d1ff51ab9bae479/outspend/6
# fetching https://mempool.space/api/tx/31e7f28dc03a9b5edd9bcb2c3f320b8bfa3b2f7fa521303a7bd27702b6b182aa
# cur_pos = ('31e7f28dc03a9b5edd9bcb2c3f320b8bfa3b2f7fa521303a7bd27702b6b182aa', 3419885054), cur_height = 615716, n_transfer = 240
# fetching https://mempool.space/api/tx/31e7f28dc03a9b5edd9bcb2c3f320b8bfa3b2f7fa521303a7bd27702b6b182aa/outspend/7
# fetching https://mempool.space/api/tx/f1b09851a41dd7c14b47483319482046a764a773ee4f7fd22d925e105f640132
# cur_pos = ('f1b09851a41dd7c14b47483319482046a764a773ee4f7fd22d925e105f640132', 3400095268), cur_height = 615718, n_transfer = 241
# fetching https://mempool.space/api/tx/f1b09851a41dd7c14b47483319482046a764a773ee4f7fd22d925e105f640132/outspend/6
# fetching https://mempool.space/api/tx/3a48c6c5388c47f411283d123b293b153f6fe83c87956ffab415a509adc5a90e
# cur_pos = ('3a48c6c5388c47f411283d123b293b153f6fe83c87956ffab415a509adc5a90e', 3395444438), cur_height = 615721, n_transfer = 242
# fetching https://mempool.space/api/tx/3a48c6c5388c47f411283d123b293b153f6fe83c87956ffab415a509adc5a90e/outspend/0
# fetching https://mempool.space/api/tx/bb4252755a501c06baa7b98c44b510096ca3beda943559a9bc09dbbcf5d25ed5
# cur_pos = ('bb4252755a501c06baa7b98c44b510096ca3beda943559a9bc09dbbcf5d25ed5', 3395444438), cur_height = 615723, n_transfer = 243
# fetching https://mempool.space/api/tx/bb4252755a501c06baa7b98c44b510096ca3beda943559a9bc09dbbcf5d25ed5/outspend/6
# fetching https://mempool.space/api/tx/82dc762919c438a76993106b249134c5e4217b562ba5867e8b51d0df7739779a
# cur_pos = ('82dc762919c438a76993106b249134c5e4217b562ba5867e8b51d0df7739779a', 3391224050), cur_height = 615727, n_transfer = 244
# fetching https://mempool.space/api/tx/82dc762919c438a76993106b249134c5e4217b562ba5867e8b51d0df7739779a/outspend/4
# fetching https://mempool.space/api/tx/4c50276f055c76d4d627c3d556a05a319252fb5576401a299e1d178400d03feb
# cur_pos = ('4c50276f055c76d4d627c3d556a05a319252fb5576401a299e1d178400d03feb', 3372623476), cur_height = 615729, n_transfer = 245
# fetching https://mempool.space/api/tx/4c50276f055c76d4d627c3d556a05a319252fb5576401a299e1d178400d03feb/outspend/4
# fetching https://mempool.space/api/tx/b1beea707a5ba17c157a3a8f8f00b95cd22d25f9184ca35eff062a1d163396d8
# cur_pos = ('b1beea707a5ba17c157a3a8f8f00b95cd22d25f9184ca35eff062a1d163396d8', 3353998316), cur_height = 615733, n_transfer = 246
# fetching https://mempool.space/api/tx/b1beea707a5ba17c157a3a8f8f00b95cd22d25f9184ca35eff062a1d163396d8/outspend/1
# fetching https://mempool.space/api/tx/1af11dfb781110494c5fb0240285f99b3e71b14223919a5f243116353aa07203
# cur_pos = ('1af11dfb781110494c5fb0240285f99b3e71b14223919a5f243116353aa07203', 3353719924), cur_height = 615737, n_transfer = 247
# fetching https://mempool.space/api/tx/1af11dfb781110494c5fb0240285f99b3e71b14223919a5f243116353aa07203/outspend/0
# fetching https://mempool.space/api/tx/e8a5e5a4a6b180b661b3a3562612abc5bbdeb01d838cc3b184d2356127cb747c
# cur_pos = ('e8a5e5a4a6b180b661b3a3562612abc5bbdeb01d838cc3b184d2356127cb747c', 3353719924), cur_height = 615739, n_transfer = 248
# fetching https://mempool.space/api/tx/e8a5e5a4a6b180b661b3a3562612abc5bbdeb01d838cc3b184d2356127cb747c/outspend/8
# fetching https://mempool.space/api/tx/4ac420f14d4a3c981bd772d43521817a8a8922fb5c82ab591cf423d95c321a89
# cur_pos = ('4ac420f14d4a3c981bd772d43521817a8a8922fb5c82ab591cf423d95c321a89', 3334467217), cur_height = 615746, n_transfer = 249
# fetching https://mempool.space/api/tx/4ac420f14d4a3c981bd772d43521817a8a8922fb5c82ab591cf423d95c321a89/outspend/6
# fetching https://mempool.space/api/tx/34ddce07d8e39d50fa6d10000e5debb8ab75da07ff66b6dd1d87c488830d962d
# cur_pos = ('34ddce07d8e39d50fa6d10000e5debb8ab75da07ff66b6dd1d87c488830d962d', 3329387915), cur_height = 615759, n_transfer = 250
# fetching https://mempool.space/api/tx/34ddce07d8e39d50fa6d10000e5debb8ab75da07ff66b6dd1d87c488830d962d/outspend/1
# fetching https://mempool.space/api/tx/6f671ea03fa0b1902a5bf563663d16c4ca1028549b00142124f10f0576d7151c
# cur_pos = ('6f671ea03fa0b1902a5bf563663d16c4ca1028549b00142124f10f0576d7151c', 3329164294), cur_height = 615763, n_transfer = 251
# fetching https://mempool.space/api/tx/6f671ea03fa0b1902a5bf563663d16c4ca1028549b00142124f10f0576d7151c/outspend/0
# fetching https://mempool.space/api/tx/5189a2c829ce2681b9cd57bffb29665a842b15d444069ec26ec50e8b90ba0a08
# cur_pos = ('5189a2c829ce2681b9cd57bffb29665a842b15d444069ec26ec50e8b90ba0a08', 3329164294), cur_height = 615765, n_transfer = 252
# fetching https://mempool.space/api/tx/5189a2c829ce2681b9cd57bffb29665a842b15d444069ec26ec50e8b90ba0a08/outspend/2
# fetching https://mempool.space/api/tx/c1a3c302cb962f46361379588dbab9512addba4e9bf22505815cef2fee034660
# cur_pos = ('c1a3c302cb962f46361379588dbab9512addba4e9bf22505815cef2fee034660', 3328495896), cur_height = 615767, n_transfer = 253
# fetching https://mempool.space/api/tx/c1a3c302cb962f46361379588dbab9512addba4e9bf22505815cef2fee034660/outspend/10
# fetching https://mempool.space/api/tx/6f01120a3e3b8be14d88ca2093f4b91fd72ab74e01699b81e1e9472b6ba039d9
# cur_pos = ('6f01120a3e3b8be14d88ca2093f4b91fd72ab74e01699b81e1e9472b6ba039d9', 3317587898), cur_height = 615768, n_transfer = 254
# fetching https://mempool.space/api/tx/6f01120a3e3b8be14d88ca2093f4b91fd72ab74e01699b81e1e9472b6ba039d9/outspend/2
# fetching https://mempool.space/api/tx/6fb05fdd97be69df6d810be8052572ac1049393c86967bec15db5321fa91b461
# cur_pos = ('6fb05fdd97be69df6d810be8052572ac1049393c86967bec15db5321fa91b461', 3306492933), cur_height = 615768, n_transfer = 255
# fetching https://mempool.space/api/tx/6fb05fdd97be69df6d810be8052572ac1049393c86967bec15db5321fa91b461/outspend/13
# fetching https://mempool.space/api/tx/d4b8215d5d8205296d2a8bb61fd59408ec0b25ad389a2bb5863b5291a27d56fa
# cur_pos = ('d4b8215d5d8205296d2a8bb61fd59408ec0b25ad389a2bb5863b5291a27d56fa', 3206363277), cur_height = 615778, n_transfer = 256
# fetching https://mempool.space/api/tx/d4b8215d5d8205296d2a8bb61fd59408ec0b25ad389a2bb5863b5291a27d56fa/outspend/2
# fetching https://mempool.space/api/tx/c4296f3ae8be40f1defbe7a9d59c496b31eb3cd592108d4dba48c09ee10d23bf
# cur_pos = ('c4296f3ae8be40f1defbe7a9d59c496b31eb3cd592108d4dba48c09ee10d23bf', 3206017134), cur_height = 615778, n_transfer = 257
# fetching https://mempool.space/api/tx/c4296f3ae8be40f1defbe7a9d59c496b31eb3cd592108d4dba48c09ee10d23bf/outspend/0
# fetching https://mempool.space/api/tx/064c3e1ce3a3bfe258c5549748a23fbecf613077442369cb36086fdaf1a5b0c7
# cur_pos = ('064c3e1ce3a3bfe258c5549748a23fbecf613077442369cb36086fdaf1a5b0c7', 3206017134), cur_height = 615780, n_transfer = 258
# fetching https://mempool.space/api/tx/064c3e1ce3a3bfe258c5549748a23fbecf613077442369cb36086fdaf1a5b0c7/outspend/6
# fetching https://mempool.space/api/tx/8043a0c4310ec2441957ee2a87aca37e4f8730b134b6fa1fd854d3e9bb200809
# cur_pos = ('8043a0c4310ec2441957ee2a87aca37e4f8730b134b6fa1fd854d3e9bb200809', 3199795184), cur_height = 615781, n_transfer = 259
# fetching https://mempool.space/api/tx/8043a0c4310ec2441957ee2a87aca37e4f8730b134b6fa1fd854d3e9bb200809/outspend/9
# fetching https://mempool.space/api/tx/3821f371d6dde508dbce858773cca754436fb63f2650823adb1ef322c3e96420
# cur_pos = ('3821f371d6dde508dbce858773cca754436fb63f2650823adb1ef322c3e96420', 3187122787), cur_height = 615787, n_transfer = 260
# fetching https://mempool.space/api/tx/3821f371d6dde508dbce858773cca754436fb63f2650823adb1ef322c3e96420/outspend/9
# fetching https://mempool.space/api/tx/eed728a33611c3a40362aa744d584fad7ac11d78eab610dd94c25f74b3d786fb
# cur_pos = ('eed728a33611c3a40362aa744d584fad7ac11d78eab610dd94c25f74b3d786fb', 3160795795), cur_height = 615790, n_transfer = 261
# fetching https://mempool.space/api/tx/eed728a33611c3a40362aa744d584fad7ac11d78eab610dd94c25f74b3d786fb/outspend/13
# fetching https://mempool.space/api/tx/202ed8d7f3d2a8fc062aadaa5b5743293decae1e17080c4fbd16b41c5ef78d73
# cur_pos = ('202ed8d7f3d2a8fc062aadaa5b5743293decae1e17080c4fbd16b41c5ef78d73', 3144772422), cur_height = 615790, n_transfer = 262
# fetching https://mempool.space/api/tx/202ed8d7f3d2a8fc062aadaa5b5743293decae1e17080c4fbd16b41c5ef78d73/outspend/6
# fetching https://mempool.space/api/tx/6e0149652f12acf697207dbaec8e7648f27836136be28a4bd5dd633a84261351
# cur_pos = ('6e0149652f12acf697207dbaec8e7648f27836136be28a4bd5dd633a84261351', 3074448911), cur_height = 615790, n_transfer = 263
# fetching https://mempool.space/api/tx/6e0149652f12acf697207dbaec8e7648f27836136be28a4bd5dd633a84261351/outspend/0
# fetching https://mempool.space/api/tx/0c12c03a0dbf0b467116e52e03524c7b0e37b828a1db2f55cb08138a7bc5af56
# cur_pos = ('0c12c03a0dbf0b467116e52e03524c7b0e37b828a1db2f55cb08138a7bc5af56', 3074448911), cur_height = 615790, n_transfer = 264
# fetching https://mempool.space/api/tx/0c12c03a0dbf0b467116e52e03524c7b0e37b828a1db2f55cb08138a7bc5af56/outspend/2
# fetching https://mempool.space/api/tx/18555c1cb31a34dd3d2d5497e7d415b660601935c51bd6888b8054a8e4489d79
# cur_pos = ('18555c1cb31a34dd3d2d5497e7d415b660601935c51bd6888b8054a8e4489d79', 3073784648), cur_height = 615793, n_transfer = 265
# fetching https://mempool.space/api/tx/18555c1cb31a34dd3d2d5497e7d415b660601935c51bd6888b8054a8e4489d79/outspend/9
# fetching https://mempool.space/api/tx/cc3d273ec856fe1673cb97a10dd3d6a13168d5142b573054be9478b38b675540
# cur_pos = ('cc3d273ec856fe1673cb97a10dd3d6a13168d5142b573054be9478b38b675540', 3032920055), cur_height = 615795, n_transfer = 266
# fetching https://mempool.space/api/tx/cc3d273ec856fe1673cb97a10dd3d6a13168d5142b573054be9478b38b675540/outspend/6
# fetching https://mempool.space/api/tx/f7346235ac0a7d744d7d0be31e6263895c8206c3efb9d16b30a5ca1f2186f112
# cur_pos = ('f7346235ac0a7d744d7d0be31e6263895c8206c3efb9d16b30a5ca1f2186f112', 3029267212), cur_height = 615797, n_transfer = 267
# fetching https://mempool.space/api/tx/f7346235ac0a7d744d7d0be31e6263895c8206c3efb9d16b30a5ca1f2186f112/outspend/8
# fetching https://mempool.space/api/tx/2cc51e268e301c1f247832ddd2f311de484da87073d6b7dbcc2b512a13bc8a2d
# cur_pos = ('2cc51e268e301c1f247832ddd2f311de484da87073d6b7dbcc2b512a13bc8a2d', 3022269927), cur_height = 615801, n_transfer = 268
# fetching https://mempool.space/api/tx/2cc51e268e301c1f247832ddd2f311de484da87073d6b7dbcc2b512a13bc8a2d/outspend/22
# fetching https://mempool.space/api/tx/601b922d7826140ec70268f6ff2d1ce81d0ee3b44265797978f3581e48e0385b
# cur_pos = ('601b922d7826140ec70268f6ff2d1ce81d0ee3b44265797978f3581e48e0385b', 2988232027), cur_height = 615805, n_transfer = 269
# fetching https://mempool.space/api/tx/601b922d7826140ec70268f6ff2d1ce81d0ee3b44265797978f3581e48e0385b/outspend/6
# fetching https://mempool.space/api/tx/795a5f8a76e1dd2fd2790052ba72ea07ae182a73ece63bb7ee75a55650113068
# cur_pos = ('795a5f8a76e1dd2fd2790052ba72ea07ae182a73ece63bb7ee75a55650113068', 2961588902), cur_height = 615817, n_transfer = 270
# fetching https://mempool.space/api/tx/795a5f8a76e1dd2fd2790052ba72ea07ae182a73ece63bb7ee75a55650113068/outspend/4
# fetching https://mempool.space/api/tx/109d0c76d07ae2bce8c1775577bb611ac5f0171c83cf4f8b953b23e408eeb3bc
# cur_pos = ('109d0c76d07ae2bce8c1775577bb611ac5f0171c83cf4f8b953b23e408eeb3bc', 2930364785), cur_height = 615821, n_transfer = 271
# fetching https://mempool.space/api/tx/109d0c76d07ae2bce8c1775577bb611ac5f0171c83cf4f8b953b23e408eeb3bc/outspend/21
# fetching https://mempool.space/api/tx/7ea16825d34d9635c8ad545eaab519ee2f4f0b188d6eccab805f74124b183f99
# cur_pos = ('7ea16825d34d9635c8ad545eaab519ee2f4f0b188d6eccab805f74124b183f99', 2864657752), cur_height = 615824, n_transfer = 272
# fetching https://mempool.space/api/tx/7ea16825d34d9635c8ad545eaab519ee2f4f0b188d6eccab805f74124b183f99/outspend/5
# fetching https://mempool.space/api/tx/62b9e89ce64b863697f648a8f336910ccb1156caaa9cd100b709f2682363441c
# cur_pos = ('62b9e89ce64b863697f648a8f336910ccb1156caaa9cd100b709f2682363441c', 2852508483), cur_height = 615826, n_transfer = 273
# fetching https://mempool.space/api/tx/62b9e89ce64b863697f648a8f336910ccb1156caaa9cd100b709f2682363441c/outspend/4
# fetching https://mempool.space/api/tx/7ba3bad27948f64eae9e8b85c28dfa004031a98202d2806a678681462fc12035
# cur_pos = ('7ba3bad27948f64eae9e8b85c28dfa004031a98202d2806a678681462fc12035', 2742175683), cur_height = 615826, n_transfer = 274
# fetching https://mempool.space/api/tx/7ba3bad27948f64eae9e8b85c28dfa004031a98202d2806a678681462fc12035/outspend/18
# fetching https://mempool.space/api/tx/b86652dc60147e9a57d47a2612f111d4779bb9df777dc509575ceac04ddecae2
# cur_pos = ('b86652dc60147e9a57d47a2612f111d4779bb9df777dc509575ceac04ddecae2', 2564026736), cur_height = 615829, n_transfer = 275
# fetching https://mempool.space/api/tx/b86652dc60147e9a57d47a2612f111d4779bb9df777dc509575ceac04ddecae2/outspend/2
# fetching https://mempool.space/api/tx/03b6a1a43a710c177f37c08cf13f6bc41e5e58f6d1eb397828d7e6b838f7e254
# cur_pos = ('03b6a1a43a710c177f37c08cf13f6bc41e5e58f6d1eb397828d7e6b838f7e254', 2559008926), cur_height = 615830, n_transfer = 276
# fetching https://mempool.space/api/tx/03b6a1a43a710c177f37c08cf13f6bc41e5e58f6d1eb397828d7e6b838f7e254/outspend/18
# fetching https://mempool.space/api/tx/4095990e8efb0352c14ab4c283501185786f894fec8e95e8564e8c321a47507e
# cur_pos = ('4095990e8efb0352c14ab4c283501185786f894fec8e95e8564e8c321a47507e', 2549060445), cur_height = 615837, n_transfer = 277
# fetching https://mempool.space/api/tx/4095990e8efb0352c14ab4c283501185786f894fec8e95e8564e8c321a47507e/outspend/17
# fetching https://mempool.space/api/tx/839c62792039d0b35ab678a6971a702b91824c765a30c2a75c19b20f202c083a
# cur_pos = ('839c62792039d0b35ab678a6971a702b91824c765a30c2a75c19b20f202c083a', 2451014117), cur_height = 615847, n_transfer = 278
# fetching https://mempool.space/api/tx/839c62792039d0b35ab678a6971a702b91824c765a30c2a75c19b20f202c083a/outspend/3
# fetching https://mempool.space/api/tx/9fe4505d0c1bff1a0d81c1bf07eedc4ce74461bd57417b4cb44012406e0c1b8a
# cur_pos = ('9fe4505d0c1bff1a0d81c1bf07eedc4ce74461bd57417b4cb44012406e0c1b8a', 2448087887), cur_height = 615849, n_transfer = 279
# fetching https://mempool.space/api/tx/9fe4505d0c1bff1a0d81c1bf07eedc4ce74461bd57417b4cb44012406e0c1b8a/outspend/2
# fetching https://mempool.space/api/tx/77f0564fc349feead0dd2bb85f716dbd65cb7ce0dc9d8cc09da4a08cdef5f1f8
# cur_pos = ('77f0564fc349feead0dd2bb85f716dbd65cb7ce0dc9d8cc09da4a08cdef5f1f8', 2447458733), cur_height = 615849, n_transfer = 280
# fetching https://mempool.space/api/tx/77f0564fc349feead0dd2bb85f716dbd65cb7ce0dc9d8cc09da4a08cdef5f1f8/outspend/14
# fetching https://mempool.space/api/tx/3b2d5fe696fb95e604a2f7d1b4d9b68dcea78a48909a9708ba73fb2e7bd8ad66
# cur_pos = ('3b2d5fe696fb95e604a2f7d1b4d9b68dcea78a48909a9708ba73fb2e7bd8ad66', 2387686912), cur_height = 615852, n_transfer = 281
# fetching https://mempool.space/api/tx/3b2d5fe696fb95e604a2f7d1b4d9b68dcea78a48909a9708ba73fb2e7bd8ad66/outspend/6
# fetching https://mempool.space/api/tx/992bf99529cc6f9fa08b86c82bf2b31a18892ef83218dcc08b5017e586a45aec
# cur_pos = ('992bf99529cc6f9fa08b86c82bf2b31a18892ef83218dcc08b5017e586a45aec', 2300060402), cur_height = 615859, n_transfer = 282
# fetching https://mempool.space/api/tx/992bf99529cc6f9fa08b86c82bf2b31a18892ef83218dcc08b5017e586a45aec/outspend/0
# fetching https://mempool.space/api/tx/5aa38ab220fff5c30cf06c44662cd965649031b681930b530717934ffd549ff3
# cur_pos = ('5aa38ab220fff5c30cf06c44662cd965649031b681930b530717934ffd549ff3', 2300060402), cur_height = 615862, n_transfer = 283
# fetching https://mempool.space/api/tx/5aa38ab220fff5c30cf06c44662cd965649031b681930b530717934ffd549ff3/outspend/5
# fetching https://mempool.space/api/tx/6ffbb7c23c28f4aef9d36c5e75995d14d3711672a793e1f901d3c976b688eab5
# cur_pos = ('6ffbb7c23c28f4aef9d36c5e75995d14d3711672a793e1f901d3c976b688eab5', 2263189109), cur_height = 615866, n_transfer = 284
# fetching https://mempool.space/api/tx/6ffbb7c23c28f4aef9d36c5e75995d14d3711672a793e1f901d3c976b688eab5/outspend/3
# fetching https://mempool.space/api/tx/62412e4874a4e39011a450d72bdb2ac8bdb0b0cfe3dfebc25b9517d79ba5519c
# cur_pos = ('62412e4874a4e39011a450d72bdb2ac8bdb0b0cfe3dfebc25b9517d79ba5519c', 2122331692), cur_height = 615866, n_transfer = 285
# fetching https://mempool.space/api/tx/62412e4874a4e39011a450d72bdb2ac8bdb0b0cfe3dfebc25b9517d79ba5519c/outspend/4
# fetching https://mempool.space/api/tx/6a26c9d0a5f5cc57823b05d08dbce39804759fcff92bb3a610f4bc529b5d7c5d
# cur_pos = ('6a26c9d0a5f5cc57823b05d08dbce39804759fcff92bb3a610f4bc529b5d7c5d', 2115288352), cur_height = 615869, n_transfer = 286
# fetching https://mempool.space/api/tx/6a26c9d0a5f5cc57823b05d08dbce39804759fcff92bb3a610f4bc529b5d7c5d/outspend/9
# fetching https://mempool.space/api/tx/21a214287c08cee2732bfcb7864174c258b812b24aaef9ca0625b52b4152aa19
# cur_pos = ('21a214287c08cee2732bfcb7864174c258b812b24aaef9ca0625b52b4152aa19', 1968373267), cur_height = 615872, n_transfer = 287
# fetching https://mempool.space/api/tx/21a214287c08cee2732bfcb7864174c258b812b24aaef9ca0625b52b4152aa19/outspend/3
# fetching https://mempool.space/api/tx/5c7e3a68246986e527083493815fe649d3398a46ad8a5c5d3a5222547b8667fe
# cur_pos = ('5c7e3a68246986e527083493815fe649d3398a46ad8a5c5d3a5222547b8667fe', 1879986713), cur_height = 615879, n_transfer = 288
# fetching https://mempool.space/api/tx/5c7e3a68246986e527083493815fe649d3398a46ad8a5c5d3a5222547b8667fe/outspend/0
# fetching https://mempool.space/api/tx/73e471388b29dbee5a34fe423bc86320e0d9f8c9b2a5dba7734aa72da8eb2d57
# cur_pos = ('73e471388b29dbee5a34fe423bc86320e0d9f8c9b2a5dba7734aa72da8eb2d57', 1879986713), cur_height = 615927, n_transfer = 289
# fetching https://mempool.space/api/tx/73e471388b29dbee5a34fe423bc86320e0d9f8c9b2a5dba7734aa72da8eb2d57/outspend/13
# fetching https://mempool.space/api/tx/cf314e745c984d677582932b9658edbf5e04b471866756b0d0c0caa9dc5bedcb
# cur_pos = ('cf314e745c984d677582932b9658edbf5e04b471866756b0d0c0caa9dc5bedcb', 1862282409), cur_height = 615937, n_transfer = 290
# fetching https://mempool.space/api/tx/cf314e745c984d677582932b9658edbf5e04b471866756b0d0c0caa9dc5bedcb/outspend/6
# fetching https://mempool.space/api/tx/600d6dcc52c83ba36cc52a2da4aa2ac0362e8c7df94c24a00e1a65899d260276
# cur_pos = ('600d6dcc52c83ba36cc52a2da4aa2ac0362e8c7df94c24a00e1a65899d260276', 1860012560), cur_height = 615940, n_transfer = 291
# fetching https://mempool.space/api/tx/600d6dcc52c83ba36cc52a2da4aa2ac0362e8c7df94c24a00e1a65899d260276/outspend/23
# fetching https://mempool.space/api/tx/a2c5b9e8895e47c887a3a3e4c36af83b7ec77e899e64d8ebcbf3692f790253be
# cur_pos = ('a2c5b9e8895e47c887a3a3e4c36af83b7ec77e899e64d8ebcbf3692f790253be', 1829044686), cur_height = 615940, n_transfer = 292
# fetching https://mempool.space/api/tx/a2c5b9e8895e47c887a3a3e4c36af83b7ec77e899e64d8ebcbf3692f790253be/outspend/6
# fetching https://mempool.space/api/tx/29a7f3fa34affcbc3987db7252642ba0e0a96f9dd8ae7c1ba8275fd900bfc1e4
# cur_pos = ('29a7f3fa34affcbc3987db7252642ba0e0a96f9dd8ae7c1ba8275fd900bfc1e4', 1821965903), cur_height = 615943, n_transfer = 293
# fetching https://mempool.space/api/tx/29a7f3fa34affcbc3987db7252642ba0e0a96f9dd8ae7c1ba8275fd900bfc1e4/outspend/5
# fetching https://mempool.space/api/tx/5a91acbcc7bd93903ad93e4fc33d3dfbf055fd51da8e5a9b9c9f9743635831fa
# cur_pos = ('5a91acbcc7bd93903ad93e4fc33d3dfbf055fd51da8e5a9b9c9f9743635831fa', 1819198660), cur_height = 615943, n_transfer = 294
# fetching https://mempool.space/api/tx/5a91acbcc7bd93903ad93e4fc33d3dfbf055fd51da8e5a9b9c9f9743635831fa/outspend/10
# fetching https://mempool.space/api/tx/e7d80630beb681a07ad562e82cffd5eb42392bdc5cef896136107dc7c519a5df
# cur_pos = ('e7d80630beb681a07ad562e82cffd5eb42392bdc5cef896136107dc7c519a5df', 1796574317), cur_height = 615945, n_transfer = 295
# fetching https://mempool.space/api/tx/e7d80630beb681a07ad562e82cffd5eb42392bdc5cef896136107dc7c519a5df/outspend/17
# fetching https://mempool.space/api/tx/ed0991988488d99ca757c93aa1fe2942d09559036e18706b65737aea489439c5

# %% [markdown]
# ### 3. 计算一个UTXO中包含的聪的所有编号？
#
# 一个当前的UTXO，表示的是一个到现在为止还没有被花费掉的 TX OUTPUT。
#
# 一个历史的UTXO，表示的是历史上该 TX OUTPUT没有被花费掉，后来某个时刻被花费掉了。
#
# 一个UTXO包含了多少聪，就有多少个聪编号。比如一个UTXO包含了一个btc，也就是 $ 10^8 $ 聪，那就是 $10^8$ 个编号。一一列举出这些编号，往往是复杂的。
#
# 不过，对于某些UTXO，这事儿还是简单，比如一个空块儿的coinbase的output。这些output的聪编号是连续的，所以知道了第一个聪的编号，就能直接知道所有聪的编号。这里说到空块儿，是因为如果不是空块儿，那么coinbase的output中就会包含所有交易的手续费中包含的聪，那这些聪编号就复杂了。
